# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # LOADINGB THE CSV FILE

# %%
cars=pd.read_csv('C:/Users/aksha/Documents/tyres.csv')

# %%
cars[:50]
# Out:
#     Brand         Model             Submodel   Tyre Brand  \
# 0   Maruti  Swift Dzire         LDI (Diesel)       JKTyre
# 1   Maruti  Swift Dzire         LDI (Diesel)         CEAT
# 2   Maruti  Swift Dzire         LDI (Diesel)       Apollo
# 3   Maruti  Swift Dzire         LDI (Diesel)  Continental
# 4   Maruti  Swift Dzire         LDI (Diesel)     GoodYear
# 5   Maruti  Swift Dzire         LDI (Diesel)       JKTyre
# 6   Maruti  Swift Dzire         LDI (Diesel)    Firestone
# 7   Maruti  Swift Dzire         LDI (Diesel)       JKTyre
# 8   Maruti  Swift Dzire         LDI (Diesel)  BridgeStone
# 9   Maruti  Swift Dzire         LDI (Diesel)  BridgeStone
# 10  Maruti  Swift Dzire         LDI (Diesel)  BridgeStone
# 11  Maruti  Swift Dzire         LDI (Diesel)  BridgeStone
# 12  Maruti  Swift Dzire         LDI (Diesel)         CEAT
# 13  Maruti  Swift Dzire         LDI (Diesel)         CEAT
# 14  Maruti  Swift Dzire         LDI (Diesel)       Falken
# ...

# %%
cars[-50:]
# Out:
#       Brand        Model Submodel   Tyre Brand            Serial No.  \
# 4300  Maruti    Stingray  Vxi (O)     Yokohama          Earth-1 E400
# 4301  Maruti    Stingray  Vxi AMT     Yokohama          Earth-1 E400
# 4302  Maruti  Swift Deca      VDI       Apollo        Amazer 4G Life
# 4303  Maruti  Swift Deca      VXI       Apollo        Amazer 4G Life
# 4304  Maruti  Swift Deca      VDI  BridgeStone          Ecopia EP150
# 4305  Maruti  Swift Deca      VDI  BridgeStone         B-Series B290
# 4306  Maruti  Swift Deca      VDI  BridgeStone          Turanza T005
# 4307  Maruti  Swift Deca      VDI  BridgeStone         S-Series S248
# 4308  Maruti  Swift Deca      VXI  BridgeStone          Ecopia EP150
# 4309  Maruti  Swift Deca      VXI  BridgeStone         B-Series B290
# 4310  Maruti  Swift Deca      VXI  BridgeStone          Turanza T005
# 4311  Maruti  Swift Deca      VXI  BridgeStone         S-Series S248
# 4312  Maruti  Swift Deca      VDI         CEAT             Milage X3
# ...

# %% [markdown]
# # ITERATING THE DATA

# %%
cars.describe()
# Out:
#         Load Index       Rating
# count  4350.000000  2248.000000
# mean     84.101609     4.297598
# std       6.716769     0.698433
# min      69.000000     1.900000
# 25%      79.000000     4.000000
# 50%      86.000000     4.300000
# 75%      88.000000     5.000000
# max     106.000000     5.000000

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4350 entries, 0 to 4349
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           4350 non-null   object
#  1   Model           4350 non-null   object
#  2   Submodel        4350 non-null   object
#  3   Tyre Brand      4350 non-null   object
#  4   Serial No.      4350 non-null   object
#  5   Type            4350 non-null   object
#  6   Load Index      4350 non-null   int64
#  7   Size            4350 non-null   object
#  8   Selling Price   4350 non-null   object
#  9   Original Price  4350 non-null   object
#  10  Rating          2248 non-null   float64
# dtypes: float64(1), int64(1), object(9)
# memory usage: 374.0+ KB

# %%
cars.nunique()
# Out:
# Brand               1
# Model              34
# Submodel          178
# Tyre Brand         16
# Serial No.        114
# Type                2
# Load Index         27
# Size               47
# Selling Price     368
# Original Price    371
# Rating             22
# dtype: int64

# %%
cars.shape
# Out:
# (4350, 11)

# %%
cars.dtypes
# Out:
# Brand              object
# Model              object
# Submodel           object
# Tyre Brand         object
# Serial No.         object
# Type               object
# Load Index          int64
# Size               object
# Selling Price      object
# Original Price     object
# Rating            float64
# dtype: object

# %%
cars.columns
# Out:
# Index(['Brand ', 'Model', 'Submodel', 'Tyre Brand', 'Serial No.', 'Type',
#        'Load Index', 'Size', 'Selling Price', 'Original Price', 'Rating'],
#       dtype='object')

# %% [markdown]
# # CHECKING FOR NULL VALUES

# %%
cars.isnull().sum()
# Out:
# Brand                0
# Model                0
# Submodel             0
# Tyre Brand           0
# Serial No.           0
# Type                 0
# Load Index           0
# Size                 0
# Selling Price        0
# Original Price       0
# Rating            2102
# dtype: int64

# %% [markdown]
# # FILLING ZEROS IN EMPTY CELLS

# %%
cars2 = cars.fillna({'Rating':0})

# %%
cars2[:50]
# Out:
#     Brand         Model             Submodel   Tyre Brand  \
# 0   Maruti  Swift Dzire         LDI (Diesel)       JKTyre
# 1   Maruti  Swift Dzire         LDI (Diesel)         CEAT
# 2   Maruti  Swift Dzire         LDI (Diesel)       Apollo
# 3   Maruti  Swift Dzire         LDI (Diesel)  Continental
# 4   Maruti  Swift Dzire         LDI (Diesel)     GoodYear
# 5   Maruti  Swift Dzire         LDI (Diesel)       JKTyre
# 6   Maruti  Swift Dzire         LDI (Diesel)    Firestone
# 7   Maruti  Swift Dzire         LDI (Diesel)       JKTyre
# 8   Maruti  Swift Dzire         LDI (Diesel)  BridgeStone
# 9   Maruti  Swift Dzire         LDI (Diesel)  BridgeStone
# 10  Maruti  Swift Dzire         LDI (Diesel)  BridgeStone
# 11  Maruti  Swift Dzire         LDI (Diesel)  BridgeStone
# 12  Maruti  Swift Dzire         LDI (Diesel)         CEAT
# 13  Maruti  Swift Dzire         LDI (Diesel)         CEAT
# 14  Maruti  Swift Dzire         LDI (Diesel)       Falken
# ...

# %%
cars[-50:]
# Out:
#       Brand        Model Submodel   Tyre Brand            Serial No.  \
# 4300  Maruti    Stingray  Vxi (O)     Yokohama          Earth-1 E400
# 4301  Maruti    Stingray  Vxi AMT     Yokohama          Earth-1 E400
# 4302  Maruti  Swift Deca      VDI       Apollo        Amazer 4G Life
# 4303  Maruti  Swift Deca      VXI       Apollo        Amazer 4G Life
# 4304  Maruti  Swift Deca      VDI  BridgeStone          Ecopia EP150
# 4305  Maruti  Swift Deca      VDI  BridgeStone         B-Series B290
# 4306  Maruti  Swift Deca      VDI  BridgeStone          Turanza T005
# 4307  Maruti  Swift Deca      VDI  BridgeStone         S-Series S248
# 4308  Maruti  Swift Deca      VXI  BridgeStone          Ecopia EP150
# 4309  Maruti  Swift Deca      VXI  BridgeStone         B-Series B290
# 4310  Maruti  Swift Deca      VXI  BridgeStone          Turanza T005
# 4311  Maruti  Swift Deca      VXI  BridgeStone         S-Series S248
# 4312  Maruti  Swift Deca      VDI         CEAT             Milage X3
# ...

# %%
cars2.isnull().sum()
# Out:
# Brand             0
# Model             0
# Submodel          0
# Tyre Brand        0
# Serial No.        0
# Type              0
# Load Index        0
# Size              0
# Selling Price     0
# Original Price    0
# Rating            0
# dtype: int64

# %% [markdown]
# # VISUALISATION

# %% [markdown]
# # A)PAIRPLOT

# %%
sns.pairplot(cars2)

# %% [markdown]
# # B)HEATMAP

# %%
sns.heatmap(cars2.corr(),annot=True,cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # C)COUNTING VALUES IN DATASET

# %%
cars2['Model'].value_counts()[:20]
# Out:
# Ciaz                634
# Ertiga              350
# Alto                301
# Swift Dzire         242
# Vitara Brezza       236
# Alto K10            224
# Ritz                222
# Dzire               216
# Esteem              215
# New Swift (2018)    198
# SX4                 195
# Celerio             184
# Swift Dzire 2008    146
# Omni                120
# Celerio X           104
# Zen Estilo          100
# A-Star              100
# Wagon R              97
# Eeco                 80
# Swift                75
# Name: Model, dtype: int64

# %%
cars2['Submodel'].value_counts()[:20]
# Out:
# ZDI (Diesel)           225
# LDI (Diesel)           119
# Diesel ZDi +           117
# Vxi(Petrol)             98
# LXI (Petrol)            96
# ZDi + AMT               94
# Zxi(Petrol)             77
# Vdi(Diesel)             73
# VXI (Petrol)            72
# VDI (Diesel)            70
# Vxi                     66
# Petrol                  57
# Lxi(Petrol)             48
# ZDi+ MT                 48
# LXI Option (Petrol)     47
# VDi AMT                 47
# LXi                     43
# Diesel                  41
# LXI(Petrol)             39
# VXI(Petrol)             39
# Name: Submodel, dtype: int64

# %%
cars2['Tyre Brand'].value_counts()[:20]
# Out:
# BridgeStone    610
# GoodYear       501
# CEAT           449
# JKTyre         445
# Apollo         400
# Yokohama       379
# Continental    339
# Falken         269
# MRF            263
# Firestone      171
# UltraMile      149
# Michelin       130
# Pirelli        104
# Hankook         65
# Kumho           57
# Maxxis          19
# Name: Tyre Brand, dtype: int64

# %%
cars2['Serial No.'].value_counts()[:20]
# Out:
# Milage X3                   196
# Amazer 4G Life              185
# B-Series B290               180
# Earth-1 E400                169
# FR500                       167
# UM 551                      141
# FuelSmart                   139
# Comfort Contact CC6         129
# Ecopia EP150                119
# Assurance Duraplus 2        109
# Sincera835                  104
# Turanza T005                 99
# Energy XM2                   97
# Assurance Triplemax          97
# Taximaxx                     96
# BluEarth AE50                86
# Duraplus                     79
# BluEarth-GT AE51             78
# ContiComfort Contact CC5     75
# Cinturato P6                 71
# Name: Serial No., dtype: int64

# %%
cars2['Type'].value_counts()[:20]
# Out:
# Tubeless    4061
# Tube         289
# Name: Type, dtype: int64

# %%
cars2['Load Index'].value_counts()[:20]
# Out:
# 88     1450
# 85      641
# 74      362
# 79      271
# 81      216
# 73      190
# 92      174
# 75      163
# 87      146
# 71      129
# 95      115
# 82       95
# 91       88
# 99       49
# 90       48
# 69       41
# 86       37
# 78       36
# 89       32
# 102      22
# Name: Load Index, dtype: int64

# %%
cars2["Size"].value_counts()
# Out:
# 185/65 R 15    1265
# 165/80 R 14     633
# 145/80 R 12     410
# 155/80 R 13     274
# 165/70 R 14     234
# 155/65 R 13     190
# 205/60 R 16     183
# 215/60 R 16     173
# 195/55 R 16     162
# 145/70 R 13     145
# 185/70 R 14     127
# 155/65 R 14     105
# 175/70 R 13      95
# 155 R 13         80
# 195/65 R 15      75
# 145/80 R 13      63
# 185/65 R 14      37
# 225/65 R 17      24
# 185/70 R14       20
# 215/55 R 17      14
# 225/70 R 16       3
# 185/70 R 19       3
# 205/70 R 17       3
# 205/70 R 16       3
# 205/70 R 18       3
# 185/70 R 20       3
# 205/70 R 15       3
# 145/70 R 20       1
# 185/70 R 16       1
# 185/70 R 15       1
# 185/70 R 25       1
# 185/70 R 23       1
# 145/70 R 12       1
# 185/70 R 26       1
# 185/70 R 22       1
# 145/70 R 17       1
# 145/70 R 19       1
# 185/70 R 28       1
# 145/70 R 15       1
# 225/70 R 17       1
# 145/70 R 16       1
# 185/70 R 29       1
# 185/70 R 24       1
# 185/70 R 21       1
# 185/70 R 27       1
# ...

# %% [markdown]
# # D)COUNTPLOT

# %%
sns.set_style('darkgrid')

# %%
sns.countplot(x="Type", data=cars2,palette = "Set2");

# %%
sns.countplot(x="Load Index", data=cars2,palette = "Set3");

# %%
 sns.countplot(x="Rating", hue="Type", data=cars2[:15])
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='count'>

# %%
sns.countplot(x="Tyre Brand", hue="Type", data=cars2[:15])
# Out:
# <AxesSubplot:xlabel='Tyre Brand', ylabel='count'>

# %%
sns.countplot(x="Size", hue="Type", data=cars2[:25])
# Out:
# <AxesSubplot:xlabel='Size', ylabel='count'>

# %% [markdown]
# # E)HISTPLOT

# %%
sns.histplot(data=cars2, x="Rating", hue="Type", multiple="stack")
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Count'>

# %% [markdown]
# # F)LINEPLOT

# %%
sns.lineplot(data=cars2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # G)STRIPPLOT

# %%
sns.stripplot(y = cars2['Rating'], x = cars2['Type'])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Rating'>

# %% [markdown]
# # H)SCATTERPLOT

# %%
sns.scatterplot(x ='Selling Price', y ='Original Price', data =cars2, hue = 'Type',hue_order= ['Tube', 'Tubeless'])
# Out:
# <AxesSubplot:xlabel='Selling Price', ylabel='Original Price'>
